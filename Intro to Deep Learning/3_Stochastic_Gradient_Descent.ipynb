# %% [markdown]
# # Stochastic Gradiant Descent
#
# Reference: [Kaggle](https://www.kaggle.com/code/ryanholbrook/stochastic-gradient-descent/tutorial)
#
# - how to train a neural netrwork?
#
# ### What do we need?
#
# - training set - adjusting the weight
# - testing set
# - *loss function**
# - *optimzer*

# %% [markdown]
# ## Loss Function
#
# - this is how we tell a network *what* problem to solve
# - **loss function** measures the disparity between the target's true value and the value the model predicts
#     - MSE
#     - MAE
#     - Huber loss
# - during the training, the model will use the loss function as a guide for finding the correct values of its weights (lower loss is better)

# %% [markdown]
# ## Optimizer - Stochastic Gradiant Descent (SGD)
#
# - how to solve our problem
# - the **optmizer** is an algorithm that adjust the weights to minimize the loss
# - vistually all the optimization algorithms used in deep learning belong to a family called **stochastic gradiant descent**
#     - iterative algorithms that train a network in steps
#
# One **step** of training goes like this:
# 1. Sample some training data and run it through the network to make prediction
# 2. Measure the loss between the prediction and the true values
# 3. Finally, adjust the weights in a direction that makes the loss smaller
#
# Then just do this over and over until the loss is a small as you like.
#
# Each iteration's sample of training data is called a minibatch (or often just "batch"), while a complete round of the training data is called an epoch. The number of epochs you train for is how many times the network will see each training example.

# %% [markdown]
# ### Learning rate and Batch Size
#
# - the **learning rate** is a number that determines the size of the shifts in the direction of each batch,
# - a small value means the networks need to see more minibatchers before its weights converge to their best values
# - the learning rate and the size of the minibatches are the two parameters that have the largest effect on how the SGD training proceeds
# - usually we use **Adam**, a SGD algorithm that has a adaptive learning rate that akes suitable for most problems without any parameter tuning (self tuning)

# %% [markdown]
# To add this to out model:
#
# ```
# model.compile(
#     optimizer="adam",
#     loss="mae",
# )
# ```

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

# %% [markdown]
# # Example

# %%
from IPython.display import display

red_wine = pd.read_csv('red-wine.csv')

# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))

# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
print(f'Train: X->{X_train.shape}, y->{y_train.shape}')
print(f'Valid: X->{X_valid.shape}, y->{y_valid.shape}')
# Out:
# Train: X->(1119, 11), y->(1119,)
# Valid: X->(480, 11), y->(480,)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[11]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

# %%
model.compile(
    optimizer='adam',
    loss='mae',
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=10,
)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 1s 212ms/step - loss: 0.3805 - val_loss: 0.1406
# Epoch 2/10
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1405 - val_loss: 0.1361
# Epoch 3/10
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1262 - val_loss: 0.1261
# Epoch 4/10
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1212 - val_loss: 0.1256
# Epoch 5/10
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1161 - val_loss: 0.1096
# Epoch 6/10
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1157 - val_loss: 0.1105
# Epoch 7/10
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1073 - val_loss: 0.1038
# Epoch 8/10
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1054 - val_loss: 0.1034
# Epoch 9/10
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1063 - val_loss: 0.1046
# Epoch 10/10
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1017 - val_loss: 0.1022

# %%
# convert the training history to a dataframe
history_df = pd.DataFrame(history.history)
# use Pandas native plot method
history_df['loss'].plot();

# %%
model.evaluate(X_valid,y_valid)  # loss on the validation set
# Out:
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1022
# 0.10224618762731552

# %%
from sklearn.metrics import mean_absolute_error

y_pred_valid = model.predict(X_valid)
mean_absolute_error(y_valid.values, y_pred_valid.reshape(1,-1)[0])   # loss on the validation set
# Out:
# 0.10224617868661881

# %% [markdown]
# # Exercise

# %%
abalone = pd.read_csv('abalone.csv')
print(abalone.shape)
# Out:
# (4177, 9)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

X = abalone.copy()
# Remove target
y = X.pop('Rings')

preprocessor = make_column_transformer(
    (StandardScaler(),
     make_column_selector(dtype_include=np.number)),
    (OneHotEncoder(sparse=False),
     make_column_selector(dtype_include=object)),
)

X = preprocessor.fit_transform(X)
y = np.log(y) # log transform target instead of standardizing

input_shape = [X.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [10]

# %%
model = keras.Sequential([
    layers.Dense(2000, activation='relu', input_shape=input_shape),
    layers.Dense(2000, activation='relu'),    
    layers.Dense(100, activation='relu'),
    layers.Dense(1),
])

# %%
model.compile(optimizer='adam', loss='mae')

# %% [markdown]
# Experimenting with the values...

# %%
history = model.fit(
    X, y,
    batch_size=256,
    epochs=200,
)
# Out:
# Epoch 1/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0675
# Epoch 2/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0744
# Epoch 3/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0755
# Epoch 4/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0756: 0s - loss
# Epoch 5/200
# 17/17 [==============================] - 1s 77ms/step - loss: 0.0750
# Epoch 6/200
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0737
# Epoch 7/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0749
# Epoch 8/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0756
# Epoch 9/200
# 17/17 [==============================] - 1s 88ms/step - loss: 0.0772
# Epoch 10/200
# 17/17 [==============================] - 2s 96ms/step - loss: 0.0734
# Epoch 11/200
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0740
# Epoch 12/200
# 17/17 [==============================] - 2s 90ms/step - loss: 0.0768
# Epoch 13/200
# 17/17 [==============================] - 2s 90ms/step - loss: 0.0734
# Epoch 14/200
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0737: 0s - lo
# Epoch 15/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0723
# Epoch 16/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0699
# Epoch 17/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0696
# Epoch 18/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0711
# Epoch 19/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0706
# Epoch 20/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0720
# Epoch 21/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0754
# Epoch 22/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0740
# Epoch 23/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0716
# Epoch 24/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0711
# Epoch 25/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0703
# Epoch 26/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0707
# Epoch 27/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0721
# Epoch 28/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0707
# Epoch 29/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0709
# Epoch 30/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0703
# Epoch 31/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0707
# Epoch 32/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0687
# Epoch 33/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0695
# Epoch 34/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0702
# Epoch 35/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0700
# Epoch 36/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0700
# Epoch 37/200
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0696
# Epoch 38/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0720
# Epoch 39/200
# 17/17 [==============================] - 2s 98ms/step - loss: 0.0692
# Epoch 40/200
# 17/17 [==============================] - 2s 87ms/step - loss: 0.0678
# Epoch 41/200
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0703: 0s - loss:
# Epoch 42/200
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0701
# Epoch 43/200
# 17/17 [==============================] - 2s 91ms/step - loss: 0.0681
# Epoch 44/200
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0696
# Epoch 45/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0708
# Epoch 46/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0702
# Epoch 47/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0677
# Epoch 48/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0679
# Epoch 49/200
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0695: 0s - loss
# Epoch 50/200
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0682
# Epoch 51/200
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0678
# Epoch 52/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0683
# Epoch 53/200
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0676
# Epoch 54/200
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0684: 1s -
# Epoch 55/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0680
# Epoch 56/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0687
# Epoch 57/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0680
# Epoch 58/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0692
# Epoch 59/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0684
# Epoch 60/200
# 17/17 [==============================] - 1s 87ms/step - loss: 0.0659
# Epoch 61/200
# 17/17 [==============================] - 1s 85ms/step - loss: 0.0659: 1s
# Epoch 62/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0669
# Epoch 63/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0656
# Epoch 64/200
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0659: 0s - loss: 0.06
# Epoch 65/200
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0661
# Epoch 66/200
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0673
# Epoch 67/200
# 17/17 [==============================] - 2s 88ms/step - loss: 0.0679
# Epoch 68/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0674
# Epoch 69/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0664
# Epoch 70/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0694
# Epoch 71/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0679
# Epoch 72/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0665
# Epoch 73/200
# 17/17 [==============================] - 2s 97ms/step - loss: 0.0678
# Epoch 74/200
# 17/17 [==============================] - 2s 91ms/step - loss: 0.0650
# Epoch 75/200
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0658: 1s -
# Epoch 76/200
# 17/17 [==============================] - 1s 86ms/step - loss: 0.0656
# Epoch 77/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0657
# Epoch 78/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0655
# Epoch 79/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0652
# Epoch 80/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0680
# Epoch 81/200
# 17/17 [==============================] - 1s 84ms/step - loss: 0.0660
# Epoch 82/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0660
# Epoch 83/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0647
# Epoch 84/200
# 17/17 [==============================] - 2s 89ms/step - loss: 0.0625
# Epoch 85/200
# 17/17 [==============================] - 2s 90ms/step - loss: 0.0641
# Epoch 86/200
# 17/17 [==============================] - 2s 95ms/step - loss: 0.0627
# Epoch 87/200
# 17/17 [==============================] - 2s 92ms/step - loss: 0.0648
# Epoch 88/200
# 17/17 [==============================] - 2s 91ms/step - loss: 0.0672
# Epoch 89/200
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0650
# Epoch 90/200
# 17/17 [==============================] - 2s 93ms/step - loss: 0.0631
# Epoch 91/200
# 17/17 [==============================] - 2s 92ms/step - loss: 0.0636
# Epoch 92/200
# 17/17 [==============================] - 2s 94ms/step - loss: 0.0653: 1s -
# Epoch 93/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0639
# Epoch 94/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0647
# Epoch 95/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0665
# Epoch 96/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0640
# Epoch 97/200
# 17/17 [==============================] - 1s 83ms/step - loss: 0.0641
# Epoch 98/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0645
# Epoch 99/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0633
# Epoch 100/200
# 17/17 [==============================] - 1s 81ms/step - loss: 0.0621
# Epoch 101/200
# 17/17 [==============================] - 1s 77ms/step - loss: 0.0632
# Epoch 102/200
# 17/17 [==============================] - 1s 77ms/step - loss: 0.0635
# Epoch 103/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0638
# Epoch 104/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0613
# Epoch 105/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0613
# Epoch 106/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0609
# Epoch 107/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0625
# Epoch 108/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0614
# Epoch 109/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0642
# Epoch 110/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0627
# Epoch 111/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0636
# Epoch 112/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0646
# Epoch 113/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0634
# Epoch 114/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0622
# Epoch 115/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0610
# Epoch 116/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0611
# Epoch 117/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0593
# Epoch 118/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0594
# Epoch 119/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0616
# Epoch 120/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0635
# Epoch 121/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0627
# Epoch 122/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0634
# Epoch 123/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0625
# Epoch 124/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0609
# Epoch 125/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0609
# Epoch 126/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0611
# Epoch 127/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0604
# Epoch 128/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0607
# Epoch 129/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0606
# Epoch 130/200
# 17/17 [==============================] - 1s 80ms/step - loss: 0.0599
# Epoch 131/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0618
# Epoch 132/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0617
# Epoch 133/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0606
# Epoch 134/200
# 17/17 [==============================] - 1s 69ms/step - loss: 0.0584
# Epoch 135/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0599
# Epoch 136/200
# 17/17 [==============================] - 1s 69ms/step - loss: 0.0595
# Epoch 137/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0593
# Epoch 138/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0599
# Epoch 139/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0594
# Epoch 140/200
# 17/17 [==============================] - 1s 79ms/step - loss: 0.0590
# Epoch 141/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0602
# Epoch 142/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0600
# Epoch 143/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0605
# Epoch 144/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0608
# Epoch 145/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0615
# Epoch 146/200
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0619
# Epoch 147/200
# 17/17 [==============================] - 1s 77ms/step - loss: 0.0632
# Epoch 148/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0610
# Epoch 149/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0603
# Epoch 150/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0590
# Epoch 151/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0579
# Epoch 152/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0575
# Epoch 153/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0610
# Epoch 154/200
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0596
# Epoch 155/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0581
# Epoch 156/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0598
# Epoch 157/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0594
# Epoch 158/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0582
# Epoch 159/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0578
# Epoch 160/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0584
# Epoch 161/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0568
# Epoch 162/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0591
# Epoch 163/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0577
# Epoch 164/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0588
# Epoch 165/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0588
# Epoch 166/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0578
# Epoch 167/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0578
# Epoch 168/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0578
# Epoch 169/200
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0592
# Epoch 170/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0577
# Epoch 171/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0576
# Epoch 172/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0563
# Epoch 173/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0567
# Epoch 174/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0578
# Epoch 175/200
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0577
# Epoch 176/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0576
# Epoch 177/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0586
# Epoch 178/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0557
# Epoch 179/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0561
# Epoch 180/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0564
# Epoch 181/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0578
# Epoch 182/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0582
# Epoch 183/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0598
# Epoch 184/200
# 17/17 [==============================] - 1s 82ms/step - loss: 0.0574
# Epoch 185/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0576
# Epoch 186/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0568
# Epoch 187/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0570
# Epoch 188/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0566
# Epoch 189/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0549
# Epoch 190/200
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0574
# Epoch 191/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0567
# Epoch 192/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0555
# Epoch 193/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0549
# Epoch 194/200
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0571
# Epoch 195/200
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0542
# Epoch 196/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0549
# Epoch 197/200
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0559
# Epoch 198/200
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0570
# Epoch 199/200
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0557
# Epoch 200/200
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0552

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[5:, ['loss']].plot();
